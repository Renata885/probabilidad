
plt.show()

# %%
plt.boxplot(fabrica2)
plt.ylabel("Produccion em mts.")
plt.title("Produccion de la fabrica 2")
plt.show()

# %%
fig,(ax1, ax2)=plt.subplots(nrows=1,ncols=2,figsize=(9,4))
bplot1=ax1.boxplot(fabrica1,
                  vert=True,#vertical box alignment
                  patch_artist=True) #fill with color
ax1.set_title("Produccion de la fabrica 1")
bplot=ax2.boxplot(fabrica2,
                  vert=True,#vertical box alignment
                  patch_artist=True) #fill with color
ax2.set_title("Produccion de la fabrica 2")
plt.show()

# %%
##Inserta
fabrica1.append(150)
print(fabrica1)
# Out:
# [27.46, 53.71, 48.47, 79.87, 77.03, 27.83, 89.96, 80.33, 5.51, 56.03, 71.58, 27.41, 74.87, 74.19, 45.54, 46.41, 16.4, 10.59, 64.4, 36.63, 35.21, 94.54, 47.29, 91.1, 97.98, 30.53, 13.43, 42.12, 19.5, 86.0, 48.54, 37.54, 29.64, 13.28, 16.93, 50.46, 11.93, 19.04, 23.3, 89.98, 39.4, 15.91, 95.77, 7.77, 71.61, 87.93, 67.13, 19.47, 13.31, 36.49, 42.64, 53.84, 70.28, 68.1, 41.07, 47.65, 81.94, 42.9, 83.98, 35.73, 32.48, 24.51, 66.41, 47.56, 76.88, 27.06, 18.64, 61.96, 51.69, 91.37, 86.12, 32.86, 86.82, 28.35, 53.19, 49.44, 15.55, 74.65, 27.64, 29.97, 26.49, 82.58, 57.51, 24.23, 69.71, 7.67, 93.6, 96.63, 61.42, 67.55, 95.0, 86.38, 7.44, 19.04, 68.13, 60.62, 37.77, 28.03, 69.71, 67.02, 150]

# %%
fig, (ax1, ax2) = plt.subplots (nrows =1 , ncols = 2, figsize=(9,4))
bplot1 = ax1.boxplot (fabrica1,
                      vert=True,
                      patch_artist = True)
ax1.set_title ('Produccion fabrica1')
ax1.set_ylim (0, 160)

bplot2 = ax2.boxplot (fabrica1,
                      vert = True,
                      patch_artist=True)
ax2.set_title('Produccion Fabrica 1')
ax2.set_ylim (0, 100)
plt.show()

# %%
fig,(ax1, ax2)=plt.subplots(nrows=1,ncols=2,figsize=(9,5))
bplot1=ax1.boxplot(fabrica1,
                  vert=True,#vertical box alignment
                  patch_artist=True) #fill with color
ax1.set_title("Produccion de la fabrica 2")
ax1.set_ylim(0,160) #Escala uniforme
bplot=ax2.boxplot(fabrica2,
                  vert=True,#vertical box alignment
                  patch_artist=True) #fill with color
ax2.set_title("Produccion de la fabrica 2")
ax2.set_ylim(0,160) #Escala uniforme
plt.show()
