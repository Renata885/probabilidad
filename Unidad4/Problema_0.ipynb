# %% [markdown]
# <a href="https://colab.research.google.com/github/Renata885/probabilidad/blob/main/Unidad4/Problema_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Probabilidad y estadistica**
#
# **Grupo 2 Y**
#
# **Unidad 4**
#
# **Programa  Problemas de Distribución Normal**
#
# Docente:Jose Gabriel Rodriquez Rivas
#
# Alumna: Karla Renata Ortega Miranda

# %%
#Una revisión de los pesos de 500 estudiantes del ITD, evidenció que la media es de 70 kilogramos y la desviación estándar es de 4 kilogramos.
# Suponiendo que los valores se distribuyen normalmente.
#Hallar lo siguiente:
#La probabilidad de estudiantes que pesan más de 68 y menos de 72 kg.
#Cuantos estudiantes pesan más de 68 y menos de 72 kg.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

plt.figure(figsize=(6,4))
media=70
desv_std=4
peso_limite=68
total_estudiantes=500

prob_menos_68kg = norm.cdf(peso_limite, media, desv_std)
prob_mas_68kg = 1 - prob_menos_68kg
estudiantes_mas_68kg = total_estudiantes * prob_mas_68kg
print("Probabilidad de que un estudiante pese mas de 68kg", prob_mas_68kg)
print("Numero aproximado de estudiantes que pesan mas de 68kg:",estudiantes_mas_68kg)
# Out:
# Probabilidad de que un estudiante pese mas de 68kg 0.6914624612740131
# Numero aproximado de estudiantes que pesan mas de 68kg: 345.73123063700655

# %%
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)
plt.plot(x, y, "b", linewidth=2)

plt.fill_between(x, y, where=(x >= peso_limite), color="skyblue", alpha=0.5)

plt.title("Probabilidad de que un estudiante pese mas de 68kg. \n $\mu=70$, $\sigma=4$, x=500")
plt.xlabel("Peso (kg)")
plt.ylabel("Densidad de probabilidad")
plt.grid(True)
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-4129291399.py:7: SyntaxWarning: invalid escape sequence '\m'
#   plt.title("Probabilidad de que un estudiante pese mas de 68kg. \n $\mu=70$, $\sigma=4$, x=500")

# %%
plt.figure(figsize=(6,4))
media=70
desv_std=4
peso_limite=72
total_estudiantes=500
prob_menos_72kg = norm.cdf(peso_limite, media, desv_std)
estudiantes_menos_72kg = total_estudiantes * prob_menos_72kg
print("Probabilidad de que un estudiante pese menos de 72kg", prob_menos_72kg)
print("Numero aproximado de estudiantes que pesan menos de 72kg:",estudiantes_menos_72kg)
# Out:
# Probabilidad de que un estudiante pese menos de 72kg 0.6914624612740131
# Numero aproximado de estudiantes que pesan menos de 72kg: 345.73123063700655

# %%
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)
plt.plot(x, y, "b", linewidth=2)

plt.fill_between(x, y, where=(x <= peso_limite), color="skyblue", alpha=0.5)

plt.title("Probabilidad de que un estudiante pese menos de 72kg. \n $\mu=72$, $\sigma=4$, x=500")
plt.xlabel("Peso (kg)")
plt.ylabel("Densidad de probabilidad")
plt.grid(True)
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-2708674493.py:7: SyntaxWarning: invalid escape sequence '\m'
#   plt.title("Probabilidad de que un estudiante pese menos de 72kg. \n $\mu=72$, $\sigma=4$, x=500")
