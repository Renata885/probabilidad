# %% [markdown]
# <a href="https://colab.research.google.com/github/Renata885/probabilidad/blob/main/Unidad3/Ejercicio_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Probabilidad y estadistica**
#
# **Grupo 2 Y**
#
# **Unidad 3**
#
# **Programa Ejercicio 3**
#
# Docente:Jose Gabriel Rodriquez Rivas
#
# Alumna: Karla Renata Ortega Miranda

# %%
import matplotlib.pyplot as plt
#valores de la variable aletoria
x=[0,1,2,3,4,5]
p=[0.05,0.10,0.25,0.30,0.20,0.10]
#verificar suma=1
print("suma de probabilidades:",sum(p))
#grafucar distribucion
plt.stem(x,p)
plt.title("Distribucion de probabilidad")
plt.xlabel("Unidades vendidas")
plt.ylabel("probabilidad")
plt.grid(True)
plt.show()
# Out:
# suma de probabilidades: 1.0

# %%
#Iniciar una variable para acumular la suma
valor_esperado=0

#Recorre sus valores y sus probabilidades
for i in range(len(x)):
    xi=x[i]#valor de la variable aleatoria
    pi=p[i]#probabilidad de ese valor
    producto = xi * pi #multiplicar valor por su probabilidad
    valor_esperado += producto #sumar al acumulador
    #mostrar cada paso
    print (f"x = {xi}, p= {pi}, x*p = {producto:.2f}")
#mostrar resultado final
print (f"\nValor esperado (Esperanza): {valor_esperado: .2f}")
# Out:
# x = 0, p= 0.05, x*p = 0.00
# x = 1, p= 0.1, x*p = 0.10
# x = 2, p= 0.25, x*p = 0.50
# x = 3, p= 0.3, x*p = 0.90
# x = 4, p= 0.2, x*p = 0.80
# x = 5, p= 0.1, x*p = 0.50
#
# Valor esperado (Esperanza):  2.80

# %%
import math
#calcular E(X)
esperanza=0
for i in range(len(x)):
  esperanza+=x[i]*p[i]
#calcular E(x2)
esperanza_cuadrado=0
for i in range(len(x)):
  esperanza_cuadrado+=x[i]**2*p[i]


#calcular varianza y desviacion estandar
varianza=esperanza_cuadrado-esperanza**2
desviacion=math.sqrt(varianza)


#Mostrar resultados
print(f"E(X)={esperanza:.2f}")
print(f"E(X2)={esperanza_cuadrado:.2f}")
print(f"Varianza={varianza:.2f}")
print(f"Desviacion estandar={desviacion:.2f}")
# Out:
# E(X)=2.80
# E(X2)=9.50
# Varianza=1.66
# Desviacion estandar=1.29

# %%
#distrrubucion acumulada
import math
import numpy as np
import matplotlib.pyplot as plt
x=[0,1,2,3,4,5]
p=[0.05,0.10,0.25,0.30,0.20,0.10]
F=np.cumsum(p)
for xi,fi in zip(x,F):
  print(f"x={xi},F={fi:.2f}")
#graficar
plt.step(x,F,where="post")
plt.title("funcion de distribucion acumulada")
plt.xlabel("Unidades vendidas")
plt.ylabel("probabilidad")
plt.grid(True)
plt.show()
# Out:
# x=0,F=0.05
# x=1,F=0.15
# x=2,F=0.40
# x=3,F=0.70
# x=4,F=0.90
# x=5,F=1.00

# %% [markdown]
# • ¿Cuántas unidades se espera vender por semana?
#
# En promedio se esperan 2.8 unidades por semana.
#
# • ¿La demanda es estable o muy variable?
#
# La desviación estándar es ≈1.29. Comparada con la media (2.8), el coeficiente de variación ≈ 1.29/2.8 ≈ 0.46 (≈46%). Eso indica variabilidad moderada
