# %% [markdown]
# <a href="https://colab.research.google.com/github/Renata885/probabilidad/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Probabilidad y estadistica**
#
# **Grupo 2 Y**
#
# **Unidad 1**
#
# **Práctica 3 Tabla de frecuencias y regla de Sturges..**
#
# Docente:Jose Gabriel Rodriquez Rivas
#
# Alumna: Karla Renata Ortega Miranda

# %%
# basado en el LIBRO estadistica para administracion pagina 12
# creamos una lista vacia que representa la edad de 100 personas
import random
edades =[]
# Hacemos un ciclo para generar 100 numeros aleatorios qe representan la edad de las personas
for i in range(100):
  # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
  # numero aleatorio
  numero_aleatorio = random.randint(18,70)
  # Agregamos el numero aleatorio a la lista de valores
  edades.append (numero_aleatorio)
print(edades)
# Out:
# [30, 41, 62, 46, 48, 59, 31, 69, 45, 66, 30, 52, 68, 58, 44, 33, 26, 19, 60, 58, 21, 33, 32, 36, 48, 48, 22, 36, 48, 51, 36, 70, 40, 50, 34, 19, 47, 44, 48, 38, 41, 24, 69, 30, 70, 24, 30, 60, 64, 32, 70, 18, 68, 26, 70, 37, 39, 42, 62, 47, 43, 68, 19, 21, 51, 22, 33, 52, 46, 70, 18, 33, 25, 54, 46, 57, 51, 54, 28, 27, 39, 28, 52, 45, 30, 39, 49, 40, 69, 63, 21, 58, 67, 63, 53, 41, 66, 42, 50, 55]

# %%
import pandas as pd
# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame (edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    30
# 1    41
# 2    62
# 3    46
# 4    48

# %%
#Calcular la tabla de distribucion de frecuencia
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
#Imprimir la tabla de distribucion de frecuencia
print("Tabla de distribucion de frecuencias:")
tabla_frecuencias
# Out:
# Tabla de distribucion de frecuencias
#     Edad  Frecuencia
# 28    18           2
# 10    19           3
# 8     21           3
# 22    22           2
# 27    24           2
# 38    25           1
# 29    26           2
# 40    27           1
# 15    28           2
# 0     30           5
# 32    31           1
# 23    32           2
# 3     33           4
# 35    34           1
# 11    36           3
# 36    37           1
# 34    38           1
# 14    39           3
# 24    40           2
# 4     41           3
# 31    42           2
# 39    43           1
# 17    44           2
# 19    45           2
# 5     46           3
# 26    47           2
# 1     48           5
# 42    49           1
# 25    50           2
# 9     51           3
# 7     52           3
# 44    53           1
# 30    54           2
# 45    55           1
# 41    57           1
# 12    58           3
# 33    59           1
# 21    60           2
# 18    62           2
# 16    63           2
# 37    64           1
# 20    66           2
# 43    67           1
# 6     68           3
# 13    69           3
# 2     70           5

# %%
#Calcular la frecuencia relativa
tabla_frecuencias['Frecuencia relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia relativa
# 28    18           2                 0.02
# 10    19           3                 0.03
# 8     21           3                 0.03
# 22    22           2                 0.02
# 27    24           2                 0.02
# 38    25           1                 0.01
# 29    26           2                 0.02
# 40    27           1                 0.01
# 15    28           2                 0.02
# 0     30           5                 0.05
# 32    31           1                 0.01
# 23    32           2                 0.02
# 3     33           4                 0.04
# 35    34           1                 0.01
# 11    36           3                 0.03
# 36    37           1                 0.01
# 34    38           1                 0.01
# 14    39           3                 0.03
# 24    40           2                 0.02
# 4     41           3                 0.03
# 31    42           2                 0.02
# 39    43           1                 0.01
# 17    44           2                 0.02
# 19    45           2                 0.02
# 5     46           3                 0.03
# 26    47           2                 0.02
# 1     48           5                 0.05
# 42    49           1                 0.01
# 25    50           2                 0.02
# 9     51           3                 0.03
# 7     52           3                 0.03
# 44    53           1                 0.01
# 30    54           2                 0.02
# 45    55           1                 0.01
# 41    57           1                 0.01
# 12    58           3                 0.03
# 33    59           1                 0.01
# 21    60           2                 0.02
# 18    62           2                 0.02
# 16    63           2                 0.02
# 37    64           1                 0.01
# 20    66           2                 0.02
# 43    67           1                 0.01
# 6     68           3                 0.03
# 13    69           3                 0.03
# 2     70           5                 0.05

# %%
#Calcular la frecuencia porcentual
tabla_frecuencias['Frecuencia porcentual'] = tabla_frecuencias['Frecuencia'] /100* 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia relativa  Frecuencia porcentual
# 28    18           2                 0.02                    2.0
# 10    19           3                 0.03                    3.0
# 8     21           3                 0.03                    3.0
# 22    22           2                 0.02                    2.0
# 27    24           2                 0.02                    2.0
# 38    25           1                 0.01                    1.0
# 29    26           2                 0.02                    2.0
# 40    27           1                 0.01                    1.0
# 15    28           2                 0.02                    2.0
# 0     30           5                 0.05                    5.0
# 32    31           1                 0.01                    1.0
# 23    32           2                 0.02                    2.0
# 3     33           4                 0.04                    4.0
# 35    34           1                 0.01                    1.0
# 11    36           3                 0.03                    3.0
# 36    37           1                 0.01                    1.0
# 34    38           1                 0.01                    1.0
# 14    39           3                 0.03                    3.0
# 24    40           2                 0.02                    2.0
# 4     41           3                 0.03                    3.0
# 31    42           2                 0.02                    2.0
# 39    43           1                 0.01                    1.0
# 17    44           2                 0.02                    2.0
# 19    45           2                 0.02                    2.0
# 5     46           3                 0.03                    3.0
# 26    47           2                 0.02                    2.0
# 1     48           5                 0.05                    5.0
# 42    49           1                 0.01                    1.0
# 25    50           2                 0.02                    2.0
# 9     51           3                 0.03                    3.0
# 7     52           3                 0.03                    3.0
# 44    53           1                 0.01                    1.0
# 30    54           2                 0.02                    2.0
# 45    55           1                 0.01                    1.0
# 41    57           1                 0.01                    1.0
# 12    58           3                 0.03                    3.0
# 33    59           1                 0.01                    1.0
# 21    60           2                 0.02                    2.0
# 18    62           2                 0.02                    2.0
# 16    63           2                 0.02                    2.0
# 37    64           1                 0.01                    1.0
# 20    66           2                 0.02                    2.0
# 43    67           1                 0.01                    1.0
# 6     68           3                 0.03                    3.0
# 13    69           3                 0.03                    3.0
# 2     70           5                 0.05                    5.0

# %%
#Calcular la frecuencia acumulada
tabla_frecuencias['Frecuencia acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia relativa  Frecuencia porcentual  \
# 28    18           2                 0.02                    2.0
# 10    19           3                 0.03                    3.0
# 8     21           3                 0.03                    3.0
# 22    22           2                 0.02                    2.0
# 27    24           2                 0.02                    2.0
# 38    25           1                 0.01                    1.0
# 29    26           2                 0.02                    2.0
# 40    27           1                 0.01                    1.0
# 15    28           2                 0.02                    2.0
# 0     30           5                 0.05                    5.0
# 32    31           1                 0.01                    1.0
# 23    32           2                 0.02                    2.0
# 3     33           4                 0.04                    4.0
# 35    34           1                 0.01                    1.0
# 11    36           3                 0.03                    3.0
# 36    37           1                 0.01                    1.0
# 34    38           1                 0.01                    1.0
# 14    39           3                 0.03                    3.0
# 24    40           2                 0.02                    2.0
# 4     41           3                 0.03                    3.0
# 31    42           2                 0.02                    2.0
# 39    43           1                 0.01                    1.0
# 17    44           2                 0.02                    2.0
# 19    45           2                 0.02                    2.0
# 5     46           3                 0.03                    3.0
# 26    47           2                 0.02                    2.0
# 1     48           5                 0.05                    5.0
# 42    49           1                 0.01                    1.0
# 25    50           2                 0.02                    2.0
# 9     51           3                 0.03                    3.0
# 7     52           3                 0.03                    3.0
# 44    53           1                 0.01                    1.0
# 30    54           2                 0.02                    2.0
# 45    55           1                 0.01                    1.0
# 41    57           1                 0.01                    1.0
# 12    58           3                 0.03                    3.0
# 33    59           1                 0.01                    1.0
# 21    60           2                 0.02                    2.0
# 18    62           2                 0.02                    2.0
# 16    63           2                 0.02                    2.0
# 37    64           1                 0.01                    1.0
# 20    66           2                 0.02                    2.0
# 43    67           1                 0.01                    1.0
# 6     68           3                 0.03                    3.0
# 13    69           3                 0.03                    3.0
# 2     70           5                 0.05                    5.0
#
#     Frecuencia acumulada
# 28                     2
# 10                     5
# 8                      8
# 22                    10
# 27                    12
# 38                    13
# 29                    15
# 40                    16
# 15                    18
# 0                     23
# 32                    24
# 23                    26
# 3                     30
# 35                    31
# 11                    34
# 36                    35
# 34                    36
# 14                    39
# 24                    41
# 4                     44
# 31                    46
# 39                    47
# 17                    49
# 19                    51
# 5                     54
# 26                    56
# 1                     61
# 42                    62
# 25                    64
# 9                     67
# 7                     70
# 44                    71
# 30                    73
# 45                    74
# 41                    75
# 12                    78
# 33                    79
# 21                    81
# 18                    83
# 16                    85
# 37                    86
# 20                    88
# 43                    89
# 6                     92
# 13                    95
# 2                    100

# %%
#regla sturges
#1. es una regla que sirve para calcular el número de clases o intervalos idóneos en los que se debe dividir un conjunto de datos
#2 Establece que el número de clases es igual a uno más el logaritmo en base 2 del número total de datos
#c=1-log2(N)   donde N es el tamaño de la muestra

# %%
#importamos la librería de funciones matemáticas
import math

# %%
#volvemos a usar la lista de edades
print(edades)
# Out:
# [30, 41, 62, 46, 48, 59, 31, 69, 45, 66, 30, 52, 68, 58, 44, 33, 26, 19, 60, 58, 21, 33, 32, 36, 48, 48, 22, 36, 48, 51, 36, 70, 40, 50, 34, 19, 47, 44, 48, 38, 41, 24, 69, 30, 70, 24, 30, 60, 64, 32, 70, 18, 68, 26, 70, 37, 39, 42, 62, 47, 43, 68, 19, 21, 51, 22, 33, 52, 46, 70, 18, 33, 25, 54, 46, 57, 51, 54, 28, 27, 39, 28, 52, 45, 30, 39, 49, 40, 69, 63, 21, 58, 67, 63, 53, 41, 66, 42, 50, 55]

# %%
#crear un DataFrame con Las edades
df = pd.DataFrame({"Edad":edades})
df.head()
# Out:
#    Edad
# 0    30
# 1    41
# 2    62
# 3    46
# 4    48

# %%
#calcular el número de intervalos utilizando la regla sturges
n=len(edades)
k=int( 1 + math.log2(n))
print("Valor de n = ", n, " \nNúmero de intervalos =", k)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
# Crear la tabla de frecuencia
tabla_frecuencia = pd.cut( df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (47.714, 55.143]    18
# 1    (62.571, 70.0]    17
# 2  (32.857, 40.286]    15
# 3  (40.286, 47.714]    15
# 4  (17.947, 25.429]    13
# 5  (25.429, 32.857]    13
# 6  (55.143, 62.571]     9

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values (by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 4  (17.947, 25.429]    13
# 5  (25.429, 32.857]    13
# 2  (32.857, 40.286]    15
# 3  (40.286, 47.714]    15
# 0  (47.714, 55.143]    18
# 6  (55.143, 62.571]     9
# 1    (62.571, 70.0]    17

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] /n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()
# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 4  (17.947, 25.429]    13      0.13       13.0       13         0.13
# 5  (25.429, 32.857]    13      0.13       13.0       26         0.26
# 2  (32.857, 40.286]    15      0.15       15.0       41         0.41
# 3  (40.286, 47.714]    15      0.15       15.0       56         0.56
# 0  (47.714, 55.143]    18      0.18       18.0       74         0.74
# 6  (55.143, 62.571]     9      0.09        9.0       83         0.83
# 1    (62.571, 70.0]    17      0.17       17.0      100         1.00
#
#    Frec Porc Ac
# 4          13.0
# 5          26.0
# 2          41.0
# 3          56.0
# 0          74.0
# 6          83.0
# 1         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=k, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
