# %% [markdown]
# <a href="https://colab.research.google.com/github/Renata885/probabilidad/blob/main/Unidad1/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# # **Grupo 2 Y**
#
# ##  **Unidad 1**
#
# **Práctica 1: Medidas de tendencia central e Histogramas**
#
# Docente:Jose Gabriel Rodriquez Rivas
#
# Alumna: Karla Renata Ortega Miranda

# %%
from statistics import *
#Lista de calificaciones del grupo a de probabilidad
grupoa= [70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
#la funcion type nos devuelve el tipo de dato de la variable
type(grupoa)
#sacar la media(promedio) de las calificacion
promedio=sum(grupoa)/len(grupoa)
print(promedio)
#utilizar la funcion mean
#el promedio (sgunda opción)
promedio2=mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333
# 75.33333333333333

# %%
#valor de la mediana con la funcion median
mediana=median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
#multiples modas que puedan existir, en caso de que exista mas de una moda
moda2=multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %%
#tiempos que tardan los 10 alumnos para correr los 100m
#tiempo en que tardaron los 10 alumnos para recorrer los 100m(promedio o media)
tiempos100mts=[15.10,17.20,14.69,13.27,22.15,18.71,19.5,20,15.10,17.20]
print(tiempos100mts)
print("el tiempo promedio de los corredores ",mean(tiempos100mts))
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.5, 20, 15.1, 17.2]
# el tiempo promedio de los corredores  17.291999999999998

# %%
#median
mediana=median(tiempos100mts)
print("la mediana de los tiempos de los corredores es",mediana)
# Out:
# la mediana de los tiempos de los corredores es 17.2

# %%
#mode
moda=mode(tiempos100mts)
print("la moda de los tiempos es=>",moda)
# Out:
# la moda de los tiempos es=> 15.1

# %%
#multimoda
multimodas=multimode(tiempos100mts)
print("la moda de los tiempos es =>",multimodas)
# Out:
# la moda de los tiempos es => [15.1, 17.2]

# %%
#libreria para generar numeros aleatorios
import random
fabrica1=[]
for i in range(100):
    numero_aleatorio = round(random.uniform(50,100),2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [67.62, 74.12, 67.34, 99.88, 52.51, 91.14, 90.91, 90.2, 61.74, 85.85, 76.49, 55.24, 83.82, 80.95, 72.08, 84.17, 96.56, 91.08, 51.48, 79.07, 73.88, 82.07, 73.14, 84.84, 83.03, 64.07, 69.19, 90.56, 96.64, 94.18, 53.41, 88.96, 72.54, 88.24, 59.65, 84.57, 51.92, 85.24, 76.29, 50.14, 92.53, 98.33, 72.5, 91.35, 98.38, 85.11, 58.32, 98.81, 54.33, 76.33, 81.67, 73.31, 54.32, 94.22, 79.76, 59.29, 93.36, 59.84, 81.47, 91.93, 89.06, 78.82, 97.11, 69.52, 82.79, 89.47, 65.13, 59.17, 71.62, 67.92, 83.13, 95.51, 81.04, 82.38, 90.97, 76.72, 95.57, 78.38, 52.94, 92.53, 93.1, 91.16, 73.78, 75.5, 70.99, 80.13, 99.17, 77.14, 72.61, 54.27, 66.46, 78.67, 55.78, 84.03, 92.96, 97.3, 53.71, 88.4, 63.55, 51.5]

# %%
#Fabrica
fabrica2=[]
for i in range(100):
    numero_aleatorio =round(random.uniform(40,93),2)
    fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [47.8, 59.28, 50.43, 50.6, 73.08, 64.46, 83.64, 78.05, 73.3, 69.71, 41.41, 49.89, 51.87, 65.88, 40.09, 40.47, 58.88, 43.21, 80.99, 49.87, 76.99, 40.22, 73.59, 74.61, 50.82, 46.96, 71.13, 80.41, 56.02, 46.92, 72.66, 51.24, 53.46, 56.75, 86.15, 92.48, 57.13, 74.45, 75.76, 62.88, 59.55, 58.46, 43.12, 80.61, 47.41, 77.78, 81.73, 48.36, 91.3, 62.09, 50.32, 56.54, 92.65, 61.28, 88.66, 64.8, 69.55, 85.78, 43.61, 56.95, 88.22, 44.22, 68.63, 65.68, 83.86, 80.53, 44.53, 66.18, 68.72, 53.42, 84.94, 73.7, 86.04, 89.15, 84.0, 73.29, 89.86, 78.14, 91.62, 83.76, 87.01, 90.23, 66.84, 79.65, 60.85, 60.99, 92.65, 91.5, 42.23, 52.6, 88.52, 74.16, 72.3, 57.23, 46.83, 67.05, 62.35, 78.12, 46.81, 84.26]

# %%
#libreria python para graficar valores
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Producción diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fabrica 1')

# %%
#produccion diaria de la fabrica 2
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
#fab 1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("Valores de la fabrica 1")
print("la media es =",media1)
print("la mediana es=",mediana1)
print("la moda es =",moda1)
# Out:
# Valores de la fabrica 1
# la media es = 77.89959999999999
# la mediana es= 79.945
# la moda es = 92.53

# %%
#fab 2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("Valores de la fabrica 2")
print("la media es =",media2)
print("la mediana es=",mediana2)
print("la moda es =",moda2)
# Out:
# Valores de la fabrica 2
# la media es = 66.9476
# la mediana es= 66.945
# la moda es = 92.65

# %%
#HISTOGRAMAS
#generar2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas,una al lado del la otra
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#linea de colores
plt.hist(fabrica1,bins=10,alpha=0.2,color="b", edgecolor="black")
plt.axvline(media1,color="b",linestyle="dashed",linewidth=2,label="media")
plt.axvline(mediana1,color="r",linestyle="dashed",linewidth=2,label="mediana")
plt.axvline(moda1,color="y",linestyle="dashed",linewidth=2,label="moda")
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title(" Produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2,bins=10,alpha=0.2,color="b", edgecolor="black")
plt.axvline(media2,color="b",linestyle="dashed",linewidth=2,label="media2")
plt.axvline(mediana2,color="r",linestyle="dashed",linewidth=2,label="mediana2")
plt.axvline(moda2,color="y",linestyle="dashed",linewidth=2,label="moda2")
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title(" Produccion diaria de la fabrica 2")
plt.legend()
plt.show()
